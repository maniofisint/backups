# %%
from IPython.display import Image

# %%
Image('C:/Users/ali92\Documents/backups/learn/DS_codes/tamrins/tamrin2/CamScanner 10-30-2020 16.09.42_1.jpg')

# %%
Image('C:/Users/ali92\Documents/backups/learn/DS_codes/tamrins/tamrin2/CamScanner 10-30-2020 16.09.42_2.jpg')

# %%
Image('C:/Users/ali92\Documents/backups/learn/DS_codes/tamrins/tamrin2/CamScanner 10-30-2020 16.09.42_3.jpg')
